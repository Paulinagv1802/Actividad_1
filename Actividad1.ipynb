# %% [markdown]
# <a href="https://colab.research.google.com/github/Paulinagv1802/Actividad_1/blob/main/Actividad1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
   class Calcular_Edades:

    @staticmethod
    def calcular_edalber(edjuan):
        return (2 * edjuan) / 3

    @staticmethod
    def calcular_edana(edjuan):
        return (4 * edjuan) / 3

    @staticmethod
    def calcular_edmama(edjuan, edalber, edana):
        return edjuan + edalber + edana

edjuan = 9
edalber = Calcular_Edades.calcular_edalber(edjuan)
edana = Calcular_Edades.calcular_edana(edjuan)
edmama = Calcular_Edades.calcular_edmama(edjuan, edalber, edana)

# Resultado formateado
print(f"Las edades son: Alberto = {edalber}, Juan = {edjuan}, Ana = {edana}, Mamá = {edmama}")
# Out:
# Las edades son: Alberto = 6.0, Juan = 9, Ana = 12.0, Mamá = 27.0

# %%
import math

class Calculos:
    @staticmethod
    def calcular_x(x,y):
        return x + math.pow(y,2)


suma = 0
x = 20
y = 40

suma = suma + x
x = Calculos.calcular_x(x, y)

suma = suma + (x / y)

print(f"El valor de x es : {x}")
print(f"El valor de y es : {y}")
print(f"El valor de la suma es: {suma}")
# Out:
# El valor de x es : 1620.0
# El valor de y es : 40
# El valor de la suma es: 60.5

# %%
class Nomina:
    @staticmethod
    def calcular_salario_bruto(horas_trabajadas, valor_hora):
        return horas_trabajadas * valor_hora

    @staticmethod
    def calcular_valor_retefuente(porcentaje_retefuente, salario_bruto):
        return porcentaje_retefuente * salario_bruto

    @staticmethod
    def calcular_salario_neto(salario_bruto, valor_retefuente):
        return salario_bruto - valor_retefuente


# Definición de variables
    horas_trabajadas = 48.0
    valor_hora = 5000.0
    retencion = 12.5
    porcentaje_retefuente = retencion / 100

    # Cálculos usando la clase Nomina
    salario_bruto = Nomina.calcular_salario_bruto(horas_trabajadas, valor_hora)
    valor_retefuente = Nomina.calcular_valor_retefuente(porcentaje_retefuente, salario_bruto)
    salario_neto = Nomina.calcular_salario_neto(salario_bruto, valor_retefuente)

    # Impresión de resultados
    print("Salario Bruto:" , salario_bruto)
    print("Retención en la Fuente: ", valor_retefuente)
    print("Salario Neto:", salario_neto)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_7779/3652237546.py in <cell line: 0>()
# ----> 1 class Nomina:
#       2     @staticmethod
#       3     def calcular_salario_bruto(horas_trabajadas, valor_hora):
#       4         return horas_trabajadas * valor_hora
#       5
#
# /tmp/ipykernel_7779/3652237546.py in Nomina()
#      20
#      21     # Cálculos usando la clase Nomina
# ---> 22     salario_bruto = Nomina.calcular_salario_bruto(horas_trabajadas, valor_hora)
#      23     valor_retefuente = Nomina.calcular_valor_retefuente(porcentaje_retefuente, salario_bruto)
#      24     salario_neto = Nomina.calcular_salario_neto(salario_bruto, valor_retefuente)
#
# NameError: name 'Nomina' is not defined

# %%
import math


class Calculos:
    @staticmethod
    def calcular_cuadrado(numero):
        return math.pow(numero, 2)

    @staticmethod
    def calcular_cubo(numero):
        return math.pow(numero, 3)



    numero = 4.0

    # Llamada a los métodos estáticos de la clase Calculos
    cuadrado = Calculos.calcular_cuadrado(numero)
    cubo = Calculos.calcular_cubo(numero)

    print("Cuadrado:" , cuadrado)
    print("Cubo:" , cubo)
# Out:
# Cuadrado: 16.0
# Cubo: 64.0

# %%
import math

class Calculos:
    @staticmethod
    def calcular_longitud_circunferencia(radio):
        # Usamos math.pi para obtener el valor de PI
        return 2 * math.pi * radio

    @staticmethod
    def calcular_area_circulo(radio):
        # Usamos math.pi y el operador ** para elevar al cuadrado
        return math.pi * math.pow(radio,2)

radio = 3.0

# Llamada a los métodos estáticos
longitud_circunferencia = Calculos.calcular_longitud_circunferencia(radio)
area_circulo = Calculos.calcular_area_circulo(radio)

# Imprimimos los resultados con f-strings
print("Longitud circunferencia: ", longitud_circunferencia)
print("Área círculo: ", area_circulo)
# Out:
# Longitud circunferencia:  18.84955592153876
# Área círculo:  28.274333882308138

# %%
class Bicycle:
    # Field or Attribute
    def __init__(self):
        self.gear = 5

    # Method
    def braking(self):
        print("reducing velocity")

# Logic from the Java main method
    # Instantiating objects
    mountain_bicycle = Bicycle()
    sports_bicycle = Bicycle()
    touring_bicycle = Bicycle()

    # Mountain Bicycle
    mountain_gear = mountain_bicycle.gear
    print("Mountain Bicycle gears: ", mountain_gear)
    mountain_bicycle.braking()

    # Sports Bicycle
    sports_gear = sports_bicycle.gear
    print("Sports Bicycle gears:", sports_gear)
    sports_bicycle.braking()

    # Touring Bicycle
    touring_gear = touring_bicycle.gear
    print("Touring Bicycle gears: ", touring_gear)
    touring_bicycle.braking()
# Out:
# Mountain Bicycle gears:  5
# reducing velocity
# Sports Bicycle gears: 5
# reducing velocity
# Touring Bicycle gears:  5
# reducing velocity

# %%
9ikm .  cclass Student:
    def __init__(self, identification, first_name, last_name):
        # In Python, 'self' is equivalent to Java's 'this'
        self.identification = identification
        self.first_name = first_name
        self.last_name = last_name

print("UNAL Students")

# Instantiating the student objects
student1 = Student(325, "catalina", "tabares")
student2 = Student(3965, "cristopher", "zuleta")
student3 = Student(3665, "aylen", "pantoja")

# Quick check: printing one of the attributes
print(f"Student 1: {student1.first_name} {student1.last_name}")
print(f"Student 2: {student2.first_name} {student2.last_name}")
print(f"Student 3: {student3.first_name} {student3.last_name}")
# Out:
# UNAL Students
# Student 1: catalina tabares
# Student 2: cristopher zuleta
# Student 3: aylen pantoja

# %%
class Persona:
    def __init__(self, nombre, apellido, numero_documento, año_nacimiento):
        self.nombre = nombre
        self.apellido = apellido
        self.numero_documento = numero_documento
        self.año_nacimiento = año_nacimiento

    def mostrar_datos_personales(self):
        print(f"Nombre = {self.nombre}")
        print(f"Apellido = {self.apellido}")
        print(f"Número de documento de identidad = {self.numero_documento}")
        print(f"Año de nacimiento = {self.año_nacimiento}")
        print()


nombre = input("Ingrese el nombre: ")
apellido = input("Ingrese el apellido: ")
numero_documento = input("Ingrese el numero de documento de identidad: ")
año_nacimiento = int(input("Ingrese el año de nacimiento: "))

persona1 = Persona(nombre, apellido, numero_documento, año_nacimiento)
persona1.mostrar_datos_personales()
# Out:
# Ingrese el nombre: Vanessa
# Ingrese el apellido: Tapias
# Ingrese el numero de documento de identidad: 2536
# Ingrese el año de nacimiento: 1994
# Nombre = Vanessa
# Apellido = Tapias
# Número de documento de identidad = 2536
# Año de nacimiento = 1994

# %%
from enum import Enum


class TipoPlaneta(Enum):
    GASEOSO = "GASEOSO"
    TERRESTRE = "TERRESTRE"
    ENANO = "ENANO"

class Planeta:
    def __init__(self, nombre, cantidad_satelites, masa, volumen, diametro, distancia_sol, tipo, es_observable):
        self.nombre = nombre
        self.cantidad_satelites = cantidad_satelites
        self.masa = masa
        self.volumen = volumen
        self.diametro = diametro
        self.distancia_sol = distancia_sol
        self.tipo = tipo
        self.es_observable = es_observable

    def imprimir(self):
        print(f"Nombre del planeta = {self.nombre}")
        print(f"Cantidad de satélites = {self.cantidad_satelites}")
        print(f"Masa del planeta = {self.masa}")
        print(f"Volumen del planeta = {self.volumen}")
        print(f"Diámetro del planeta = {self.diametro}")
        print(f"Distancia al sol = {self.distancia_sol}")
        print(f"Tipo de planeta = {self.tipo.name}")
        print(f"Es observable = {self.es_observable}")

    def calcular_densidad(self):
        # Using a simple check to avoid DivisionByZero if volumen is 0
        return self.masa / self.volumen if self.volumen != 0 else 0

    def es_planeta_exterior(self):
        # 149597870 * 3.4
        limite = 508632758.0
        return self.distancia_sol > limite

print("Ingrese el nombre :")
nombre = input()

print("Ingrese cantidad de satélites :")
cantidad_satelites = int(input())

print("Ingrese la masa :")
masa = float(input())

print("Ingrese el volumen :")
volumen = float(input())

print("Ingrese el diámetro :")
diametro = int(input())

print("Ingrese la distancia al sol :")
distancia_sol = int(input())

# Creating the instance (Hardcoded TERRESTRE and True as per your Java example)
p1 = Planeta(nombre, cantidad_satelites, masa, volumen, diametro,
                 distancia_sol, TipoPlaneta.TERRESTRE, True)

print("*********************************")
p1.imprimir()
print(f"Densidad del planeta = {p1.calcular_densidad()}")
print(f"Es planeta exterior = {p1.es_planeta_exterior()}")
print("*********************************")
# Out:
# Ingrese el nombre :
# tierra
# Ingrese cantidad de satélites :
# 1
# Ingrese la masa :
# 234234
# Ingrese el volumen :
# 2343
# Ingrese el diámetro :
# 3423456
# Ingrese la distancia al sol :
# 2342345
# *********************************
# Nombre del planeta = tierra
# Cantidad de satélites = 1
# Masa del planeta = 234234.0
# Volumen del planeta = 2343.0
# Diámetro del planeta = 3423456
# Distancia al sol = 2342345
# Tipo de planeta = TERRESTRE
# Es observable = True
# Densidad del planeta = 99.97183098591549
# Es planeta exterior = False
# *********************************
